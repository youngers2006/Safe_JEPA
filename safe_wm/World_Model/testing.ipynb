# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
from Q_safety_critic import SafetyCriticEnsemble

# %%
d_latent = 3 
d_action = 3
safety_ensemble_size = 2
rngs = nnx.Rngs(0)

safety_critic = SafetyCriticEnsemble(
            ensemble_size=safety_ensemble_size,
            d_in=d_latent + d_action,
            hidden_features=(10, 10),
            d_out=1,
            rngs=rngs      
        )
target_critic = SafetyCriticEnsemble(
            ensemble_size=safety_ensemble_size,
            d_in=d_latent + d_action,
            hidden_features=(10, 10),
            d_out=1,
            rngs=rngs      
        )

# %%
action = jnp.array((0.2, 0.5, 0.8))
state = jnp.array((1.0, 2.0, 3.0))
state_n = jnp.array((2.0, 12.0, 1.0))

for i in range(3):
    mu, var = safety_critic.get_moments(state, action)

# %%
loss = safety_critic.compute_loss(
    target_ensemble=target_critic,
    z=state,
    next_z_target=state_n,
    action=action,
    done=jnp.array((0)),
    discount=0.98,
    cql_alpha=1.0,
    safety_cost=0.02,
    action_bounds=(-1.0, 1.0),
    rng_key=rngs,
    Q_minima_samples=64
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 loss = safety_critic.compute_loss(
#       2     target_ensemble=target_critic,
#       3     z=state,
#       4     next_z_target=state_n,
#
# File ~/Github/Safe_JEPA/safe_wm/World_Model/Q_safety_critic.py:103, in SafetyCriticEnsemble.compute_loss(self, target_ensemble, z, next_z_target, action, safety_cost, done, discount, cql_alpha, action_bounds, rng_key, Q_minima_samples)
#      95 sampled_actions = jax.random.uniform(
#      96     random_key,
#      97     shape=(batch_size, Q_minima_samples, action.shape[-1]),
#      98     minval=action_bounds[0],
#      99     maxval=action_bounds[1]
#     100 ).reshape(-1, action.shape[-1])
#     102 z_q = jnp.repeat(jnp.expand_dims(next_z_target, axis=1), Q_minima_samples, axis=1).reshape(-1, next_z_target.shape[-1])
# --> 103 next_q = self(
#     104     z_q, sampled_actions, update_spectral_norm=False
#     105 ).squeeze().reshape(self.ensemble_size, batch_size, Q_minima_samples)
#     106 mean_next_q = jnp.mean(next_q, axis=0)
#     107 best_action_indices = jnp.argmin(mean_next_q, axis=-1)
#
# File ~/Github/Safe_JEPA/safe_wm/World_Model/Q_safety_critic.py:64, in SafetyCriticEnsemble.__call__(self, z, u, update_spectral_norm)
#      63 def __call__(self, z: jax.Array, u: jax.Array, update_spectral_norm: bool = False) -> jax.Array:
# ---> 64     return nnx.vmap(
#      65         lambda model, input_z, input_u, spectral_norm: model(input_z, input_u, spectral_norm),
#      66         in_axes=(0, None, None, None)
#      67     )(self.critic_ensemble, z, u, update_spectral_norm)
#
# File ~/miniconda3/envs/SCP_dreamer/lib/python3.12/site-packages/flax/nnx/graphlib.py:2113, in UpdateContextManager.__call__.<locals>.update_context_manager_wrapper(*args, **kwargs)
#    2110 @functools.wraps(f)
#    2111 def update_context_manager_wrapper(*args, **kwargs):
#    2112   with self:
# -> 2113     return f(*args, **kwargs)
#
# File ~/miniconda3/envs/SCP_dreamer/lib/python3.12/site-packages/flax/nnx/transforms/iteration.py:575, in vmap.<locals>.vmap_wrapper(*args, **kwargs)
#     571 args = resolve_kwargs(f, args, kwargs)
#     572 pure_args = extract.to_tree(
#     573     args, prefix=in_axes, split_fn=_vmap_split_fn, ctxtag='vmap'
#     574 )
# --> 575 pure_args_out, pure_out = vmapped_fn(*pure_args)
#     576 _args_out, out = extract.from_tree(
#     577   (pure_args_out, pure_out), ctxtag='vmap', is_inner=False
#     578 )
#     579 return out
#
#     [... skipping hidden 6 frame]
#
# File ~/miniconda3/envs/SCP_dreamer/lib/python3.12/site-packages/flax/nnx/transforms/iteration.py:341, in VmapFn.__call__(self, *pure_args)
#     336   pure_args = _update_variable_sharding_metadata(
#     337       pure_args, self.transform_metadata, spmd.remove_axis
#     338   )
#     339 args = extract.from_tree(pure_args, ctxtag='vmap', is_inner=True)
# --> 341 out = self.f(*args)
#     343 args_out = extract.clear_non_graph_nodes(args)
#     344 pure_args_out, pure_out = extract.to_tree(
#     345     (args_out, out),
#     346     prefix=(self.in_axes, self.out_axes),
#     347     split_fn=_vmap_split_fn,
#     348     ctxtag='vmap',
#     349 )
#
# File ~/Github/Safe_JEPA/safe_wm/World_Model/Q_safety_critic.py:65, in SafetyCriticEnsemble.__call__.<locals>.<lambda>(model, input_z, input_u, spectral_norm)
#      63 def __call__(self, z: jax.Array, u: jax.Array, update_spectral_norm: bool = False) -> jax.Array:
#      64     return nnx.vmap(
# ---> 65         lambda model, input_z, input_u, spectral_norm: model(input_z, input_u, spectral_norm),
#      66         in_axes=(0, None, None, None)
#      67     )(self.critic_ensemble, z, u, update_spectral_norm)
#
# File ~/Github/Safe_JEPA/safe_wm/World_Model/Q_safety_critic.py:29, in QSafetyCritic.__call__(self, z, u, update_spectral_norm)
#      28 def __call__(self, z: jax.Array, u: jax.Array, update_spectral_norm: bool = False) -> jax.Array:
# ---> 29     x = jnp.concatenate([z, u], axis=-1)
#      31     for l in range(0, len(self.layers), 2):
#      32         linear_layer = self.layers[l]
#
# File ~/miniconda3/envs/SCP_dreamer/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:4578, in concatenate(arrays, axis, dtype)
#    4576 else:
#    4577   arrays_out = [asarray(arr, dtype=dtype) for arr in arrays]
# -> 4578 return lax.concatenate(arrays_out, axis)
#
#     [... skipping hidden 23 frame]
#
# File ~/miniconda3/envs/SCP_dreamer/lib/python3.12/site-packages/jax/_src/lax/lax.py:7152, in _concatenate_shape_rule(*operands, **kwargs)
#    7148   msg = ("Cannot concatenate arrays with shapes that differ in dimensions "
#    7149          "other than the one being concatenated: concatenating along "
#    7150          "dimension {} for shapes {}.")
#    7151   shapes = [operand.shape for operand in operands]
# -> 7152   raise TypeError(msg.format(dimension, ", ".join(map(str, shapes))))
#    7154 concat_size = sum(o.shape[dimension] for o in operands)
#    7155 ex_shape = operands[0].shape
#
# TypeError: Cannot concatenate arrays with shapes that differ in dimensions other than the one being concatenated: concatenating along dimension 1 for shapes (64, 3), (192, 3).
